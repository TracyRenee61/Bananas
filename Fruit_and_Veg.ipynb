# %% [markdown]
# Import librariesd

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read csv file

# %%
data = pd.read_csv('https://raw.githubusercontent.com/TracyRenee61/Bananas/main/fruitvegprices-11jan21.csv', encoding= 'unicode_escape')
data
# Out:
#              item            variety        date  price unit
# 0          apples  bramleys_seedling  2021-01-10   1.15   kg
# 1          apples  coxs_orange_group  2021-01-10   1.20   kg
# 2          apples    egremont_russet  2021-01-10   1.71   kg
# 3          apples           braeburn  2021-01-10   0.96   kg
# 4          apples               gala  2021-01-10   0.96   kg
# ...           ...                ...         ...    ...  ...
# 26899    tomatoes               plum  2010-08-13   5.46  6kg
# 26900    tomatoes              round  2010-08-13   4.58  6kg
# 26901    tomatoes               vine  2010-08-13   3.92  6kg
# 26902      turnip      all_varieties  2010-08-13   0.95   kg
# 26903  watercress      all_varieties  2010-08-13  10.42  box
#
# [26904 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26904 entries, 0 to 26903
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   item     26904 non-null  object
#  1   variety  26904 non-null  object
#  2   date     26904 non-null  object
#  3   price    26904 non-null  float64
#  4   unit     26904 non-null  object
# dtypes: float64(1), object(4)
# memory usage: 1.0+ MB

# %% [markdown]
# Sort dataframe by date

# %%
data = data.sort_values(by='date').reset_index()
data
# Out:
#        index                   item  ...  price   unit
# 0      26903             watercress  ...  10.42    box
# 1      26871         cooking_apples  ...   0.61     kg
# 2      26870  chrysanthemum_flowers  ...   0.19  spray
# 3      26869  chrysanthemum_flowers  ...   0.50  bloom
# 4      26868          chrysanthemum  ...   1.17   each
# ...      ...                    ...  ...    ...    ...
# 26899     27                 turnip  ...   1.69     kg
# 26900     28               parsnips  ...   1.03     kg
# 26901     29                 tulips  ...   0.23   stem
# 26902     15                cabbage  ...   0.35     kg
# 26903      0                 apples  ...   1.15     kg
#
# [26904 rows x 6 columns]

# %% [markdown]
# Create group

# %%
data['Group'] = data['item'] + "-" + data['variety']
data
# Out:
#        index                   item  ...   unit                               Group
# 0      26903             watercress  ...    box            watercress-all_varieties
# 1      26871         cooking_apples  ...     kg   cooking_apples-bramley's_seedling
# 2      26870  chrysanthemum_flowers  ...  spray  chrysanthemum_flowers-indoor_spray
# 3      26869  chrysanthemum_flowers  ...  bloom  chrysanthemum_flowers-indoor_bloom
# 4      26868          chrysanthemum  ...   each                  chrysanthemum-13cm
# ...      ...                    ...  ...    ...                                 ...
# 26899     27                 turnip  ...     kg                       turnip-turnip
# 26900     28               parsnips  ...     kg              parsnips-all_varieties
# 26901     29                 tulips  ...   stem                       tulips-tulips
# 26902     15                cabbage  ...     kg                       cabbage-white
# 26903      0                 apples  ...     kg            apples-bramleys_seedling
#
# [26904 rows x 7 columns]

# %% [markdown]
# Drop columns

# %%
data = data.drop(['item', 'variety'], axis=1)
data
# Out:
#        index        date  price   unit                               Group
# 0      26903  2010-08-13  10.42    box            watercress-all_varieties
# 1      26871  2010-08-13   0.61     kg   cooking_apples-bramley's_seedling
# 2      26870  2010-08-13   0.19  spray  chrysanthemum_flowers-indoor_spray
# 3      26869  2010-08-13   0.50  bloom  chrysanthemum_flowers-indoor_bloom
# 4      26868  2010-08-13   1.17   each                  chrysanthemum-13cm
# ...      ...         ...    ...    ...                                 ...
# 26899     27  2021-01-10   1.69     kg                       turnip-turnip
# 26900     28  2021-01-10   1.03     kg              parsnips-all_varieties
# 26901     29  2021-01-10   0.23   stem                       tulips-tulips
# 26902     15  2021-01-10   0.35     kg                       cabbage-white
# 26903      0  2021-01-10   1.15     kg            apples-bramleys_seedling
#
# [26904 rows x 5 columns]

# %% [markdown]
# Count group

# %%
groups = data['Group'].to_list()

# using naive method to remove duplicated from list  
list_group = [] 
for i in groups: 
    if i not in list_group: 
        list_group.append(i) 
sorted(list_group)
# Out:
# ['alstromeria-indoor',
#  'apples-braeburn',
#  'apples-bramleys_seedling',
#  'apples-coxs_orange_group',
#  'apples-egremont_russet',
#  'apples-gala',
#  'apples-other_early_season',
#  'apples-other_late_season',
#  'apples-other_mid_season',
#  'asparagus-all_varieties',
#  'asparagus-asparagus',
#  'beans-broad',
#  'beans-dwarf_french_or_kidney',
#  'beans-runner_climbing',
#  'beetroot-beetroot',
#  'beetroot-topped',
#  'begonia_elatior-13cm',
#  'begoniaelatior-13cm',
#  'blackberries-all_varieties',
#  'blackberries-blackberries',
#  'blackcurrants-all_varieties',
#  'blueberries-blueberries',
#  'broad_beans-broad',
#  'brussels_sprouts-all_varieties',
#  'brussels_sprouts-brussels_sprouts',
#  'bulb_onions-red',
#  'bulb_onions-yellow',
#  'cabbage-red',
#  'cabbage-round_green_other',
#  'cabbage-savoy',
#  'cabbage-spring_greens_loose',
#  'cabbage-spring_greens_pre-packed',
#  'cabbage-spring_greens_prepacked',
#  'cabbage-summer_&_autumn_pointed',
#  'cabbage-summer_&_autumn_round',
#  'cabbage-summer_autumn_pointed',
#  'cabbage-summer_autumn_round',
#  'cabbage-summer_autumnpointed',
#  'cabbage-white',
#  'cabbage-winter_other',
#  'calabrese-all_varieties',
#  'calabrese-calabrese',
#  'capsicum-elongated',
#  'capsicum-green',
#  'capsicum-red',
#  'capsicum-yelloworange',
#  'capsicums-green',
#  'capsicums-red',
#  'carrots-topped_washed',
#  'carrots-toppedwashed',
#  'cauliflower-all',
#  'cauliflowers-all_other',
#  'cauliflowers-kent',
#  'celeriac-celeriac',
#  'celery-all_washed',
#  'cherries-all',
#  'cherries-sweet_black',
#  'cherries-sweet_white',
#  'chinese_leaf-chinese_leaf',
#  'chrysanthemum-13cm',
#  'chrysanthemum-indoor_spray',
#  'chrysanthemum_flowers-indoor_bloom',
#  'chrysanthemum_flowers-indoor_spray',
#  'chrysanthemums_flowers-indoorbloom',
#  'chrysanthemums_flowers-indoorspray',
#  "cooking_apples-bramley's_seedling",
#  'cooking_apples-bramleyâ\x80\x99s_seedling',
#  'coriander-coriander',
#  'courgettes-all_varieties',
#  'courgettes-courgettes',
#  'cucumbers-all_varieties',
#  'cucumbers-cucumbers',
#  'curly_kale-curly_kale',
#  'currants-black',
#  'currants-red',
#  'cyclamen-13_cm',
#  'cyclamen-13cm',
#  'damsons-all_varieties',
#  'dessert_apples-braeburn',
#  "dessert_apples-cox's_orange_group",
#  'dessert_apples-coxâ\x80\x99s_orangegroup',
#  'dessert_apples-discovery',
#  'dessert_apples-egremont_russet',
#  'dessert_apples-gala',
#  'dessert_apples-jonagold_group',
#  'dessert_apples-jonogold_group',
#  'dessert_apples-other_early_season',
#  'dessert_apples-other_late_season',
#  'dessert_apples-other_mid_season',
#  'dessert_apples-red_pippin',
#  'dessert_apples-spartan',
#  'dessert_apples-worcester_pearmain',
#  'dwarf,_french_or_kidney_beans-dwarf,_french_or_kidney',
#  'dwarf_french_or_kidney_beans-dwarf_french_or_kidney',
#  'geranium-13_cm',
#  'geranium-9_cm',
#  'gladioli-all_varieties',
#  'gooseberries-all_varieties',
#  'gooseberries-gooseberries',
#  'irises-indoor',
#  'leeks-trimmed',
#  'lettuce-butterhead_indoor',
#  'lettuce-cos',
#  'lettuce-crisp_iceberg_type',
#  'lettuce-crispiceberg_type',
#  'lettuce-little_gem',
#  'lillies-oriental',
#  'mixed_babyleaf_salad-pillow_pack',
#  'mushrooms-button_indoor',
#  'mushrooms-cup_indoor',
#  'mushrooms-flat_indoor',
#  'narcissus,_inc._daffodils-indoor',
#  'narcissus-indoor',
#  'narcissus-outdoor',
#  'narcissusincdaffodils-indoor',
#  'onion-bulb_brown',
#  'onion-bulb_red',
#  'onion-saladspring',
#  'oriental_lilies-homegrown',
#  'pak_choi-pak_choi',
#  'parsnips-all_varieties',
#  'pears-conference',
#  'pears-doyenne_du_comice',
#  'pears-other',
#  "pears-william's_bon_chretien",
#  'pears-williamâ\x80\x99s_bon_chretien',
#  'peas-shelling_all_varieties',
#  'peony-peony',
#  'pinks-all_varieties',
#  'plums-all_other',
#  'plums-victoria',
#  'plums_and_gages-czar',
#  'plums_and_gages-majorieâ\x80\x99s_seedling',
#  "plums_and_gages-marjorie's_seedling",
#  'plums_and_gages-other_varieties',
#  'plums_and_gages-victoria',
#  'poinsettia-13_cm',
#  'poinsettia-13cm',
#  'raspberries-all_varieties',
#  'raspberries-raspberries',
#  'redcurrants-all_varieties',
#  'rhubarb-forced',
#  'rhubarb-outdoor',
#  'rocket-rocket',
#  'runner_beans-runner_climbing',
#  'runner_beans-runnerclimbing',
#  'salad_onions-salad',
#  'shelling_peas-all_varieties',
#  'spinach-leaf_loose/bunches',
#  'spinach-leaf_loosebunches',
#  'spinach_lead-loosebunches',
#  'spinach_leaf-loosebunches',
#  'spring_greens-prepacked',
#  'stocks-stocks',
#  'strawberries-all_varieties',
#  'strawberries-strawberries',
#  'swede-all_varieties',
#  'swede-swede',
#  'sweet_williams-sweet_williams',
#  'sweetcorn-all_varieties',
#  'sweetcorn-sweetcorn',
#  'tomatoes-cherry',
#  'tomatoes-plum',
#  'tomatoes-round',
#  'tomatoes-vine',
#  'tulips-indoor',
#  'tulips-tulips',
#  'turnip-all_varieties',
#  'turnip-turnip',
#  'watercress-all_varieties',
#  'watercress-pillow_packs']

# %%
print(len(list_group))
# Out:
# 171

# %% [markdown]
# Dates

# %%
from datetime import date 
from datetime import timedelta

# %%
max_date = data.date.max()
max_date = pd.Timestamp(max_date)
max_date
# Out:
# Timestamp('2021-01-10 00:00:00')

# %% [markdown]
# Rename columns

# %%
data = data.drop(['unit', 'index'], axis=1)

df = data.rename(columns={'date': 'ds', 'group': 'group', 'price':'y'})
df
# Out:
#                ds      y                               Group
# 0      2010-08-13  10.42            watercress-all_varieties
# 1      2010-08-13   0.61   cooking_apples-bramley's_seedling
# 2      2010-08-13   0.19  chrysanthemum_flowers-indoor_spray
# 3      2010-08-13   0.50  chrysanthemum_flowers-indoor_bloom
# 4      2010-08-13   1.17                  chrysanthemum-13cm
# ...           ...    ...                                 ...
# 26899  2021-01-10   1.69                       turnip-turnip
# 26900  2021-01-10   1.03              parsnips-all_varieties
# 26901  2021-01-10   0.23                       tulips-tulips
# 26902  2021-01-10   0.35                       cabbage-white
# 26903  2021-01-10   1.15            apples-bramleys_seedling
#
# [26904 rows x 3 columns]

# %% [markdown]
# FB Prophet predictions on each group

# %%
from fbprophet import Prophet

final = pd.DataFrame()

grouped = df.groupby('Group')
for g in grouped.groups:
    group = grouped.get_group(g)
    m = Prophet()
    m.fit(group)
    future = m.make_future_dataframe(periods=52, freq='w')
    forecast = m.predict(future)
    #I added a column with group
    forecast['group'] = g
    #I used concat instead of merge
    final = pd.concat([final, forecast], ignore_index=True)
final
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 22.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 17.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 9.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 11.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 22.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 6.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 6.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 4.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 6.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 22.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 4.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 4.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#               ds      trend  ...       yhat                    group
# 0     2010-08-13   0.864577  ...   0.811490       alstromeria-indoor
# 1     2010-08-20   0.865964  ...   0.825968       alstromeria-indoor
# 2     2010-08-27   0.867351  ...   0.857136       alstromeria-indoor
# 3     2010-09-03   0.868738  ...   0.888236       alstromeria-indoor
# 4     2010-09-10   0.870125  ...   0.908078       alstromeria-indoor
# ...          ...        ...  ...        ...                      ...
# 33553 2020-07-26  11.920536  ...  11.920536  watercress-pillow_packs
# 33554 2020-08-02  11.968047  ...  11.968047  watercress-pillow_packs
# 33555 2020-08-09  12.015559  ...  12.015559  watercress-pillow_packs
# 33556 2020-08-16  12.063070  ...  12.063070  watercress-pillow_packs
# 33557 2020-08-23  12.110582  ...  12.110582  watercress-pillow_packs
#
# [33558 rows x 20 columns]

# %% [markdown]
# Get predictions

# %%
prediction = pd.DataFrame({'date': final.ds, 'prediction': final.yhat, 'group':final.group })
prediction
# Out:
#             date  prediction                    group
# 0     2010-08-13    0.811490       alstromeria-indoor
# 1     2010-08-20    0.825968       alstromeria-indoor
# 2     2010-08-27    0.857136       alstromeria-indoor
# 3     2010-09-03    0.888236       alstromeria-indoor
# 4     2010-09-10    0.908078       alstromeria-indoor
# ...          ...         ...                      ...
# 33553 2020-07-26   11.920536  watercress-pillow_packs
# 33554 2020-08-02   11.968047  watercress-pillow_packs
# 33555 2020-08-09   12.015559  watercress-pillow_packs
# 33556 2020-08-16   12.063070  watercress-pillow_packs
# 33557 2020-08-23   12.110582  watercress-pillow_packs
#
# [33558 rows x 3 columns]

# %% [markdown]
# Get future predictions

# %%
future_prediction = prediction[(prediction['date'] > max_date)]
future_prediction
# Out:
#             date  prediction            group
# 578   2021-01-17    0.962456  apples-braeburn
# 579   2021-01-24    0.967899  apples-braeburn
# 580   2021-01-31    0.982699  apples-braeburn
# 581   2021-02-07    0.996768  apples-braeburn
# 582   2021-02-14    0.993467  apples-braeburn
# ...          ...         ...              ...
# 33000 2021-12-12    1.454507    turnip-turnip
# 33001 2021-12-19    1.374746    turnip-turnip
# 33002 2021-12-26    1.301972    turnip-turnip
# 33003 2022-01-02    1.330662    turnip-turnip
# 33004 2022-01-09    1.440993    turnip-turnip
#
# [3263 rows x 3 columns]

# %% [markdown]
# Count groups from future predictions

# %%
groups = data['Group'].to_list()

# using naive method to remove duplicated from list  
list_group = [] 
for i in groups: 
    if i not in list_group: 
        list_group.append(i) 
sorted(list_group)
# Out:
# ['alstromeria-indoor',
#  'apples-braeburn',
#  'apples-bramleys_seedling',
#  'apples-coxs_orange_group',
#  'apples-egremont_russet',
#  'apples-gala',
#  'apples-other_early_season',
#  'apples-other_late_season',
#  'apples-other_mid_season',
#  'asparagus-all_varieties',
#  'asparagus-asparagus',
#  'beans-broad',
#  'beans-dwarf_french_or_kidney',
#  'beans-runner_climbing',
#  'beetroot-beetroot',
#  'beetroot-topped',
#  'begonia_elatior-13cm',
#  'begoniaelatior-13cm',
#  'blackberries-all_varieties',
#  'blackberries-blackberries',
#  'blackcurrants-all_varieties',
#  'blueberries-blueberries',
#  'broad_beans-broad',
#  'brussels_sprouts-all_varieties',
#  'brussels_sprouts-brussels_sprouts',
#  'bulb_onions-red',
#  'bulb_onions-yellow',
#  'cabbage-red',
#  'cabbage-round_green_other',
#  'cabbage-savoy',
#  'cabbage-spring_greens_loose',
#  'cabbage-spring_greens_pre-packed',
#  'cabbage-spring_greens_prepacked',
#  'cabbage-summer_&_autumn_pointed',
#  'cabbage-summer_&_autumn_round',
#  'cabbage-summer_autumn_pointed',
#  'cabbage-summer_autumn_round',
#  'cabbage-summer_autumnpointed',
#  'cabbage-white',
#  'cabbage-winter_other',
#  'calabrese-all_varieties',
#  'calabrese-calabrese',
#  'capsicum-elongated',
#  'capsicum-green',
#  'capsicum-red',
#  'capsicum-yelloworange',
#  'capsicums-green',
#  'capsicums-red',
#  'carrots-topped_washed',
#  'carrots-toppedwashed',
#  'cauliflower-all',
#  'cauliflowers-all_other',
#  'cauliflowers-kent',
#  'celeriac-celeriac',
#  'celery-all_washed',
#  'cherries-all',
#  'cherries-sweet_black',
#  'cherries-sweet_white',
#  'chinese_leaf-chinese_leaf',
#  'chrysanthemum-13cm',
#  'chrysanthemum-indoor_spray',
#  'chrysanthemum_flowers-indoor_bloom',
#  'chrysanthemum_flowers-indoor_spray',
#  'chrysanthemums_flowers-indoorbloom',
#  'chrysanthemums_flowers-indoorspray',
#  "cooking_apples-bramley's_seedling",
#  'cooking_apples-bramleyâ\x80\x99s_seedling',
#  'coriander-coriander',
#  'courgettes-all_varieties',
#  'courgettes-courgettes',
#  'cucumbers-all_varieties',
#  'cucumbers-cucumbers',
#  'curly_kale-curly_kale',
#  'currants-black',
#  'currants-red',
#  'cyclamen-13_cm',
#  'cyclamen-13cm',
#  'damsons-all_varieties',
#  'dessert_apples-braeburn',
#  "dessert_apples-cox's_orange_group",
#  'dessert_apples-coxâ\x80\x99s_orangegroup',
#  'dessert_apples-discovery',
#  'dessert_apples-egremont_russet',
#  'dessert_apples-gala',
#  'dessert_apples-jonagold_group',
#  'dessert_apples-jonogold_group',
#  'dessert_apples-other_early_season',
#  'dessert_apples-other_late_season',
#  'dessert_apples-other_mid_season',
#  'dessert_apples-red_pippin',
#  'dessert_apples-spartan',
#  'dessert_apples-worcester_pearmain',
#  'dwarf,_french_or_kidney_beans-dwarf,_french_or_kidney',
#  'dwarf_french_or_kidney_beans-dwarf_french_or_kidney',
#  'geranium-13_cm',
#  'geranium-9_cm',
#  'gladioli-all_varieties',
#  'gooseberries-all_varieties',
#  'gooseberries-gooseberries',
#  'irises-indoor',
#  'leeks-trimmed',
#  'lettuce-butterhead_indoor',
#  'lettuce-cos',
#  'lettuce-crisp_iceberg_type',
#  'lettuce-crispiceberg_type',
#  'lettuce-little_gem',
#  'lillies-oriental',
#  'mixed_babyleaf_salad-pillow_pack',
#  'mushrooms-button_indoor',
#  'mushrooms-cup_indoor',
#  'mushrooms-flat_indoor',
#  'narcissus,_inc._daffodils-indoor',
#  'narcissus-indoor',
#  'narcissus-outdoor',
#  'narcissusincdaffodils-indoor',
#  'onion-bulb_brown',
#  'onion-bulb_red',
#  'onion-saladspring',
#  'oriental_lilies-homegrown',
#  'pak_choi-pak_choi',
#  'parsnips-all_varieties',
#  'pears-conference',
#  'pears-doyenne_du_comice',
#  'pears-other',
#  "pears-william's_bon_chretien",
#  'pears-williamâ\x80\x99s_bon_chretien',
#  'peas-shelling_all_varieties',
#  'peony-peony',
#  'pinks-all_varieties',
#  'plums-all_other',
#  'plums-victoria',
#  'plums_and_gages-czar',
#  'plums_and_gages-majorieâ\x80\x99s_seedling',
#  "plums_and_gages-marjorie's_seedling",
#  'plums_and_gages-other_varieties',
#  'plums_and_gages-victoria',
#  'poinsettia-13_cm',
#  'poinsettia-13cm',
#  'raspberries-all_varieties',
#  'raspberries-raspberries',
#  'redcurrants-all_varieties',
#  'rhubarb-forced',
#  'rhubarb-outdoor',
#  'rocket-rocket',
#  'runner_beans-runner_climbing',
#  'runner_beans-runnerclimbing',
#  'salad_onions-salad',
#  'shelling_peas-all_varieties',
#  'spinach-leaf_loose/bunches',
#  'spinach-leaf_loosebunches',
#  'spinach_lead-loosebunches',
#  'spinach_leaf-loosebunches',
#  'spring_greens-prepacked',
#  'stocks-stocks',
#  'strawberries-all_varieties',
#  'strawberries-strawberries',
#  'swede-all_varieties',
#  'swede-swede',
#  'sweet_williams-sweet_williams',
#  'sweetcorn-all_varieties',
#  'sweetcorn-sweetcorn',
#  'tomatoes-cherry',
#  'tomatoes-plum',
#  'tomatoes-round',
#  'tomatoes-vine',
#  'tulips-indoor',
#  'tulips-tulips',
#  'turnip-all_varieties',
#  'turnip-turnip',
#  'watercress-all_varieties',
#  'watercress-pillow_packs']

# %%
print(len(list_group))
# Out:
# 171

# %% [markdown]
# Select group

# %%
origin = 'turnip-turnip'

single_prediction = future_prediction[(future_prediction['group'] == origin)]
single_prediction
# Out:
#             date  prediction          group
# 32953 2021-01-17    1.367482  turnip-turnip
# 32954 2021-01-24    1.282054  turnip-turnip
# 32955 2021-01-31    1.133015  turnip-turnip
# 32956 2021-02-07    1.042506  turnip-turnip
# 32957 2021-02-14    1.046561  turnip-turnip
# 32958 2021-02-21    1.072073  turnip-turnip
# 32959 2021-02-28    1.047324  turnip-turnip
# 32960 2021-03-07    0.995164  turnip-turnip
# 32961 2021-03-14    0.988014  turnip-turnip
# 32962 2021-03-21    1.032158  turnip-turnip
# 32963 2021-03-28    1.047862  turnip-turnip
# 32964 2021-04-04    0.987001  turnip-turnip
# 32965 2021-04-11    0.938035  turnip-turnip
# 32966 2021-04-18    1.062634  turnip-turnip
# 32967 2021-04-25    1.411755  turnip-turnip
# 32968 2021-05-02    1.833136  turnip-turnip
# 32969 2021-05-09    2.093974  turnip-turnip
# 32970 2021-05-16    2.096047  turnip-turnip
# 32971 2021-05-23    1.949940  turnip-turnip
# 32972 2021-05-30    1.835228  turnip-turnip
# 32973 2021-06-06    1.813971  turnip-turnip
# 32974 2021-06-13    1.802685  turnip-turnip
# 32975 2021-06-20    1.709493  turnip-turnip
# 32976 2021-06-27    1.555679  turnip-turnip
# 32977 2021-07-04    1.442694  turnip-turnip
# 32978 2021-07-11    1.425906  turnip-turnip
# 32979 2021-07-18    1.460197  turnip-turnip
# 32980 2021-07-25    1.473910  turnip-turnip
# 32981 2021-08-01    1.461387  turnip-turnip
# 32982 2021-08-08    1.473628  turnip-turnip
# 32983 2021-08-15    1.531439  turnip-turnip
# 32984 2021-08-22    1.586955  turnip-turnip
# 32985 2021-08-29    1.587018  turnip-turnip
# 32986 2021-09-05    1.549545  turnip-turnip
# 32987 2021-09-12    1.544851  turnip-turnip
# 32988 2021-09-19    1.602822  turnip-turnip
# 32989 2021-09-26    1.669584  turnip-turnip
# 32990 2021-10-03    1.674494  turnip-turnip
# 32991 2021-10-10    1.621372  turnip-turnip
# 32992 2021-10-17    1.582645  turnip-turnip
# 32993 2021-10-24    1.601700  turnip-turnip
# 32994 2021-10-31    1.632070  turnip-turnip
# 32995 2021-11-07    1.597130  turnip-turnip
# 32996 2021-11-14    1.495274  turnip-turnip
# 32997 2021-11-21    1.410911  turnip-turnip
# 32998 2021-11-28    1.410795  turnip-turnip
# 32999 2021-12-05    1.457241  turnip-turnip
# 33000 2021-12-12    1.454507  turnip-turnip
# 33001 2021-12-19    1.374746  turnip-turnip
# 33002 2021-12-26    1.301972  turnip-turnip
# 33003 2022-01-02    1.330662  turnip-turnip
# 33004 2022-01-09    1.440993  turnip-turnip
